# %%
import pandas as pd
import numpy as np

#encoding="utf-16"

# %%
 df = pd.read_csv("C:/Users/DELL/PycharmProjects/SMS-Spam-Detection/spam01.csv")
#ctrl + enter = excute the cell
#alt +enter = excute +create

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.tail()
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN

# %%
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 3821  ham                           Just normal only here :)        NaN
# 2187  ham        Oh god. I'm gonna Google nearby cliffs now.        NaN
# 640   ham  Well imma definitely need to restock before th...        NaN
# 1664  ham                                     ÌÏ v ma fan...        NaN
# 3705  ham  Reading gud habit.. Nan bari hudgi yorge patai...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 3821        NaN        NaN
# 2187        NaN        NaN
# 640         NaN        NaN
# 1664        NaN        NaN
# 3705        NaN        NaN

# %%
df.columns
# Out:
# Index(['v1', 'v2', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %%
df.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],inplace=True)

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.columns
# Out:
# Index(['v1', 'v2'], dtype='object')

# %%
df.rename(columns={'v1':'result', 'v2':'input'}, inplace=True)

# %%
df.head()
# Out:
#   result                                              input
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
df['result'].value_counts()
# Out:
# result
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# result    0
# input     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %%
import matplotlib.pyplot as plt
plt.pie(df['result'].value_counts(),labels=['not spam','spam'], autopct='%0.2f')
plt.show()

# %%
pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# ...

# %%
 df.head()
# Out:
#   result                                              input
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
df= df.replace({'ham':0,'spam':1})
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6512\597485661.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df= df.replace({'ham':0,'spam':1})

# %%
df.head()
# Out:
#    result                                              input
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df
# Out:
#       result                                              input
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
# [5169 rows x 2 columns]

# %% [markdown]
# EDA

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df.head()
# Out:
#    result                                              input
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df['charactersCount']=df['input'].apply(len)

# %%
df.head()
# Out:
#    result                                              input  charactersCount
# 0       0  Go until jurong point, crazy.. Available only ...              111
# 1       0                      Ok lar... Joking wif u oni...               29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              155
# 3       0  U dun say so early hor... U c already then say...               49
# 4       0  Nah I don't think he goes to usf, he lives aro...               61

# %%
from nltk.tokenize import word_tokenize

# %%
df['wordCount'] = df['input'].apply(lambda i: len(word_tokenize(i)))

# %%
df['sentanceCount'] = df['input'].apply(lambda i: len(nltk.sent_tokenize(i)))

# %%
df.head()
# Out:
#    result                                              input  charactersCount  \
# 0       0  Go until jurong point, crazy.. Available only ...              111
# 1       0                      Ok lar... Joking wif u oni...               29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              155
# 3       0  U dun say so early hor... U c already then say...               49
# 4       0  Nah I don't think he goes to usf, he lives aro...               61
#
#    wordCount  sentanceCount
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df[['charactersCount','wordCount','sentanceCount']].describe()
# Out:
#        charactersCount    wordCount  sentanceCount
# count      5169.000000  5169.000000    5169.000000
# mean         78.977945    18.455794       1.965564
# std          58.236293    13.324758       1.448541
# min           2.000000     1.000000       1.000000
# 25%          36.000000     9.000000       1.000000
# 50%          60.000000    15.000000       1.000000
# 75%         117.000000    26.000000       2.000000
# max         910.000000   220.000000      38.000000

# %%
df[df['result']==0][['charactersCount','wordCount','sentanceCount']].describe()
# Out:
#        charactersCount    wordCount  sentanceCount
# count      4516.000000  4516.000000    4516.000000
# mean         70.459256    17.123782       1.820195
# std          56.358207    13.493970       1.383657
# min           2.000000     1.000000       1.000000
# 25%          34.000000     8.000000       1.000000
# 50%          52.000000    13.000000       1.000000
# 75%          90.000000    22.000000       2.000000
# max         910.000000   220.000000      38.000000

# %%
df[df['result']==1][['charactersCount','wordCount','sentanceCount']].describe()
# Out:
#        charactersCount   wordCount  sentanceCount
# count       653.000000  653.000000     653.000000
# mean        137.891271   27.667688       2.970904
# std          30.137753    7.008418       1.488425
# min          13.000000    2.000000       1.000000
# 25%         132.000000   25.000000       2.000000
# 50%         149.000000   29.000000       3.000000
# 75%         157.000000   32.000000       4.000000
# max         224.000000   46.000000       9.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['result']==0]['charactersCount'])
sns.histplot(df[df['result']==1]['charactersCount'], color='red')
# Out:
# <Axes: xlabel='charactersCount', ylabel='Count'>

# %%
sns.histplot(df[df['result']==0]['wordCount'])
sns.histplot(df[df['result']==1]['wordCount'], color='red')
# Out:
# <Axes: xlabel='wordCount', ylabel='Count'>

# %%
sns.pairplot(df,hue='result', diag_kind="kde")

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    result                                              input  charactersCount  \
# 0       0  Go until jurong point, crazy.. Available only ...              111
# 1       0                      Ok lar... Joking wif u oni...               29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              155
# 3       0  U dun say so early hor... U c already then say...               49
# 4       0  Nah I don't think he goes to usf, he lives aro...               61
#
#    wordCount  sentanceCount
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df[df['result']==1]['input']
# Out:
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 5       FreeMsg Hey there darling it's been 3 week's n...
# 8       WINNER!! As a valued network customer you have...
# 9       Had your mobile 11 months or more? U R entitle...
# 11      SIX chances to win CASH! From 100 to 20,000 po...
#                               ...
# 5537    Want explicit SEX in 30 secs? Ring 02073162414...
# 5540    ASKED 3MOBILE IF 0870 CHATLINES INCLU IN FREE ...
# 5547    Had your contract mobile 11 Mnths? Latest Moto...
# 5566    REMINDER FROM O2: To get 2.50 pounds free call...
# 5567    This is the 2nd time we have tried 2 contact u...
# Name: input, Length: 653, dtype: object

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# from nltk.corpus import stopwords
# stopwords=stopwords.words('English')
# def transform_text(text):
#     useful_words=[]
#     text=text.lower() #lowercase
#     words=nltk.word_tokenize(text)
#     for word in words:
#         if word not in stopwords:
#             useful_words.append(word)
#     print(useful_words)
#     return " ".join(useful_words)

# %%
# transform_text("Hey, this is Ironman! -- Hey I'm Harvey Spector. ")

# %%
import string
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
def transform_text(text):
    text=text.lower()
    text=nltk.word_tokenize(text)
    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)  
    text=y[:]
    y.clear()
    stop_words=set(stopwords.words('english'))
    for i in text:
        if i not in stop_words and i not in string.punctuation:
            y.append(i)
    text=y[:]
    y.clear()
    for i in text:
        y.append(ps.stem(i))
    return " ".join(y)
    
transform_text('This is to 46487 &&*(900) MaxBlack&^(% 294 loving her life and dancing even if its raining')
# Out:
# '46487 900 maxblack 294 love life danc even rain'

# %%
df['input'][1000]
# Out:
# 'No..but heard abt tat..'

# %%
ps.stem('dancing')
# Out:
# 'danc'

# %%
df['transformed_input']=df['input'].apply(transform_text)

# %%
df.head()
# Out:
#    result                                              input  charactersCount  \
# 0       0  Go until jurong point, crazy.. Available only ...              111
# 1       0                      Ok lar... Joking wif u oni...               29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              155
# 3       0  U dun say so early hor... U c already then say...               49
# 4       0  Nah I don't think he goes to usf, he lives aro...               61
#
#    wordCount  sentanceCount                                  transformed_input
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from wordcloud import WordCloud
wc=WordCloud()

# %%
spam_wc=wc.generate(df[df['result']==1]['transformed_input'].str.cat(sep=" "))

# %%
plt.imshow(spam_wc)

# %%
ham_wc=wc.generate(df[df['result']==0]['transformed_input'].str.cat(sep=" "))
plt.imshow(spam_wc)

# %%
df.head()
# Out:
#    result                                              input  charactersCount  \
# 0       0  Go until jurong point, crazy.. Available only ...              111
# 1       0                      Ok lar... Joking wif u oni...               29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...              155
# 3       0  U dun say so early hor... U c already then say...               49
# 4       0  Nah I don't think he goes to usf, he lives aro...               61
#
#    wordCount  sentanceCount                                  transformed_input
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
spam_corpus=[]
for i in df[df['result']==1]['transformed_input'].tolist():
    for j in i.split():
        spam_corpus.append(j)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter
Counter(spam_corpus).most_common(30)
# Out:
# [('call', 320),
#  ('free', 191),
#  ('2', 155),
#  ('txt', 141),
#  ('text', 122),
#  ('u', 119),
#  ('ur', 119),
#  ('mobil', 114),
#  ('stop', 104),
#  ('repli', 103),
#  ('claim', 98),
#  ('4', 97),
#  ('prize', 82),
#  ('get', 74),
#  ('new', 64),
#  ('servic', 64),
#  ('tone', 63),
#  ('send', 60),
#  ('urgent', 57),
#  ('nokia', 57),
#  ('contact', 56),
#  ('award', 55),
#  ('phone', 52),
#  ('cash', 51),
#  ('pleas', 51),
#  ('week', 49),
#  ('win', 48),
#  ('c', 45),
#  ('collect', 45),
#  ('min', 45)]

# %%
word_counts = Counter(spam_corpus).most_common(30)
data = pd.DataFrame(word_counts, columns=["Word", "Frequency"])
sns.barplot(x="Word",y="Frequency", data =data, palette="husl")
plt.xticks(rotation='vertical')
plt.show
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6512\3947801004.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Word",y="Frequency", data =data, palette="husl")
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ham_corpus=[]
for i in df[df['result']==0]['transformed_input'].tolist():
    for j in i.split():
        ham_corpus.append(j)

# %%
df
# Out:
#       result                                              input  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
#       charactersCount  wordCount  sentanceCount  \
# 0                 111         24              2
# 1                  29          8              2
# 2                 155         37              2
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
#Bag of words
cv=CountVectorizer()
tfidf=TfidfVectorizer(max_features=3000)

# %%
#x=cv.fit_transform(df['transformed_input']).toarray()
x=tfidf.fit_transform(df['transformed_input']).toarray()

# %%
x.shape
# Out:
# (5169, 3000)

# %%
y=df['result'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(x_train,y_train)
y_pred1=gnb.predict(x_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8694390715667312
# [[788 108]
#  [ 27 111]]
# 0.5068493150684932

# %%
mnb.fit(x_train,y_train)
y_pred2=mnb.predict(x_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
bnb.fit(x_train,y_train)
y_pred3=bnb.predict(x_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %%
#tfidf->mnb chosen

# %% [markdown]
# # Model Improvement

# %%
import pickle
pickle.dump(tfidf, open('vectorizer.pkl','wb'))
pickle.dump(mnb, open('model.pkl','wb'))
